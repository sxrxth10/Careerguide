# %%
career_quiz_questions = [
    {
        "question": "You enjoy creating beautiful and easy-to-use designs.",
        "domains": {"UIUX": 2, "Web Development-frontend": 1}
    },
    {
        "question": "You like working with numbers and finding patterns in data.",
        "domains": {"Data Science": 2, "ML": 1, "AI": 1}
    },
    {
        "question": "You are interested in making apps that people use on their phones.",
        "domains": {"Mobile Development": 2, "Web Development": 1}
    },
    {
        "question": "You are curious about how to keep computers and data safe.",
        "domains": {"Cybersecurity": 2, "DevOps": 1}
    },
    {
        "question": "You enjoy exploring system settings or tools with many options, like customizing your phone or computer settings.",
        "domains": {"DevOps": 2, "Software Testing": 1}
    },
    {
        "question": "You like solving tricky puzzles or logic-based games.",
        "domains": {"ML": 2, "Backend": 2, "Data Science": 1}
    },
    {
        "question": "You are good at spotting mistakes and fixing problems.",
        "domains": {"Software Testing": 2, "Backend": 2, "cyber security":1}
    },
    {
        "question": "You like helping others work together and finish tasks on time.",
        "domains": {"Project Management": 2}
    },

    {
        "question": "You are interested in how websites work behind the scenes.",
        "domains": {"Web Development-backend": 2}
    },
    {
        "question": "You like making something from start to finish on your own.",
        "domains": {"Full Stack": 2, "Web Development": 1}
    },
    {
        "question": "You enjoy learning about smart technology that can learn or think like humans.",
        "domains": {"ML": 2, "AI": 2}
    },
    {
        "question": "You like coming up with fun ideas for games or interactive experiences.",
        "domains": {"Game Development": 2, "UIUX": 2}
    },
    {
        "question": "You want to learn how digital money or online contracts work.",
        "domains": {"Blockchain": 2, "Backend": 1}
    },
    {
        "question": "You enjoy reading about robots, self-driving cars, or chatbots.",
        "domains": {"AI": 2, "ML": 2}
    },
    {
        "question": "You would like to make apps that work on mobile phones.",
        "domains": {"Mobile Development": 2}
    },
    {
        "question": "You care about writing code that runs fast and stays safe.",
        "domains": {"Backend": 2, "Cybersecurity": 1}
    },
    {
        "question": "You like testing things and making sure they work correctly.",
        "domains": {"Software Testing": 2, "UIUX": 1}
    },
    {
        "question": "You enjoy fixing problems quickly when something breaks.",
        "domains": {"DevOps": 2, "Backend": 1}
    },
    {
        "question": "You’re good at organizing plans and making sure everything runs smoothly.",
        "domains": {"Project Management": 2}
    },
    {
        "question": "You enjoy creating fun experiences like games or interactive stories.",
        "domains": {"Game Development": 2, "Frontend": 1}
    },
    {
        "question": "You are curious about how websites or apps can run without being controlled by a company.",
        "domains": {"Blockchain": 2}
    },
    {
        "question": "You enjoy turning numbers or information into graphs or simple visuals.",
        "domains": {"Data Science": 2, "UIUX": 1}
    },
    {
        "question": "You like building the parts of a website that users don’t see but are important.",
        "domains": {"Backend": 2, "Web Development": 1}
    },
    {
        "question": "You enjoy learning new tools that help make websites look better.",
        "domains": {"Frontend": 2, "Web Development": 2}
    },
    {
        "question": "You are excited about using AI to help people or make tasks easier.",
        "domains": {"AI": 2, "ML": 2}
    },
    {
        "question": "You like when everything in a software works perfectly with no errors.",
        "domains": {"Software Testing": 2, "DevOps": 1}
    },
    {
        "question": "You are interested in creating 3D designs or virtual reality experiences.",
        "domains": {"Game Development": 2, "UIUX": 1}
    },
    {
        "question": "You like apps that use phone features like camera, GPS, or fingerprint.",
        "domains": {"Mobile Development": 2}
    },
    {
        "question": "You care about privacy and want to protect people’s data.",
        "domains": {"Cybersecurity": 2}
    },
    {
        "question": "You like using tools to plan work and track what’s done.",
        "domains": {"Project Management": 2}
    }
]

# %% [markdown]
# updatedd

# %%
career_quiz_questions = [
    {"question": "You enjoy solving puzzles or logical problems.", 
     "domains": {"ML": 2, "Data Science": 1, "Backend": 1}},

    {"question": "You like drawing, painting, or being creative.", 
     "domains": {"UIUX": 2, "Frontend": 1, "Game Development": 1}},

    {"question": "You have a strong interest in mathematics and numbers.", 
     "domains": {"ML": 2, "AI": 2, "Data Science": 1}},

    {"question": "You enjoy organizing and planning tasks for a team.", 
     "domains": {"Project Management": 2}},

    {"question": "You often notice small errors and like to fix them.", 
     "domains": {"Software Testing": 2, "Backend": 1}},

    {"question": "You enjoy making mobile apps or exploring app features.", 
     "domains": {"Mobile Development": 2}},

    {"question": "You’re curious about how websites and apps work inside.", 
     "domains": {"Backend": 2, "Web Development": 1}},

    {"question": "You enjoy designing things to look neat and user-friendly.", 
     "domains": {"UIUX": 2, "Frontend": 1}},

    {"question": "You like learning about smart technologies like robots or chatbots.", 
     "domains": {"AI": 2, "ML": 2}},

    {"question": "You are interested in how computer systems stay secure from hackers.", 
     "domains": {"Cybersecurity": 2, "DevOps": 1}},

    {"question": "You like coming up with new ideas for games or fun experiences.", 
     "domains": {"Game Development": 2, "UIUX": 1}},

    {"question": "You enjoy automating tasks so you don’t have to repeat them manually.", 
     "domains": {"DevOps": 2, "Software Testing": 1}},

    {"question": "You’re good at managing people and making sure deadlines are met.", 
     "domains": {"Project Management": 2}},

    {"question": "You enjoy experimenting with new tools or technologies.", 
     "domains": {"Full Stack": 2, "DevOps": 1}},

    {"question": "You’re curious about how cloud-based tools like Google Drive or AWS work.", 
     "domains": {"Cloud Development": 2, "DevOps": 1}},

    {"question": "You enjoy working on both visual design and technical parts of a project.", 
     "domains": {"Full Stack": 2, "Frontend": 1}},

    {"question": "You enjoy creating things that are interactive or animated.", 
     "domains": {"Game Development": 2, "Frontend": 1}},

    {"question": "You care deeply about user privacy and online safety.", 
     "domains": {"Cybersecurity": 2, "Backend": 1}},

    {"question": "You like analyzing information and finding useful insights.", 
     "domains": {"Data Science": 2, "AI": 1}},

    {"question": "You’re fascinated by digital currencies or blockchain technology.", 
     "domains": {"Blockchain": 2, "Backend": 1}},

    {"question": "You like learning how websites are built from the ground up.", 
     "domains": {"Web Development": 2, "Frontend": 1}},

    {"question": "You enjoy figuring out how to break systems (ethically) and test their limits.", 
     "domains": {"Cybersecurity": 2, "Software Testing": 1}},

    {"question": "You enjoy managing complex workflows and systems.", 
     "domains": {"Cloud Development": 2, "DevOps": 2}},

    {"question": "You have an interest in how games are programmed and designed.", 
     "domains": {"Game Development": 2}},

    {"question": "You like helping teams run smoothly and meet their goals.", 
     "domains": {"Project Management": 2}},

    {"question": "You enjoy turning ideas into working apps or tools.", 
     "domains": {"Full Stack": 2, "Web Development": 1}},

    {"question": "You prefer working on problems that have no obvious solution.", 
     "domains": {"AI": 2, "ML": 2}},

    {"question": "You enjoy testing apps to make sure they work perfectly.", 
     "domains": {"Software Testing": 2, "UIUX": 1}},

    {"question": "You often play games and wonder how they’re made.", 
     "domains": {"Game Development": 2, "Backend": 1}},

    {"question": "You like using diagrams or tools to explain big ideas to others.", 
     "domains": {"Project Management": 2, "UIUX": 1}},
]

# %% [markdown]
# updated2

# %%
career_quiz_questions = [
    {"question": "When faced with a tricky situation, you enjoy breaking it down into smaller, manageable steps.", 
     "domains": {"ML": 1, "Data Science": 1, "Backend": 1}},
     
    {"question": "You often find yourself thinking of ways to make processes more efficient or automated.", 
     "domains": {"DevOps": 2, "AI": 1}},
     
    {"question": "In your free time, you enjoy experimenting with new apps or games and figuring out how they work.", 
     "domains": {"Game Development": 1, "Frontend": 1, "Mobile Development": 1}},
     
    {"question": "You tend to think of creative solutions when something isn’t working the way it should.", 
     "domains": {"Frontend": 2, "UIUX": 1}},
     
    {"question": "You prefer tasks that require you to use both logical thinking and creativity.", 
     "domains": {"AI": 2, "ML": 2, "Game Development": 1}},
     
    {"question": "When working on a project, you like to focus on how the final product will look and how users will interact with it.", 
     "domains": {"UIUX": 2, "Frontend": 1}},
     
    {"question": "You find joy in solving puzzles or challenges that require you to think outside the box.", 
     "domains": {"ML": 2, "AI": 1, "Data Science": 1}},
     
    {"question": "You often think about how things could be more secure or protected from harm.", 
     "domains": {"Cybersecurity": 2, "Backend": 1}},
     
    {"question": "You prefer working in a structured environment where tasks are organized, but you're also comfortable handling unexpected issues.", 
     "domains": {"Project Management": 2, "DevOps": 1}},
     
    {"question": "In your free time, you like to keep up with new technologies or gadgets, always exploring how they work.", 
     "domains": {"Full Stack": 1, "AI": 1, "Blockchain": 1}},
     
    {"question": "When trying to complete a task, you prefer having clear instructions, but you also enjoy discovering new ways to improve or personalize the process.", 
     "domains": {"Software Testing": 1, "DevOps": 1}},
     
    {"question": "You enjoy activities that require a balance of strategy and quick decision-making such as team-based challenges.", 
     "domains": {"Project Management":2}},
     
    {"question": "You like being involved in planning or organizing team projects, ensuring everything runs smoothly.", 
     "domains": {"Project Management": 2, "DevOps": 1}},
     
    {"question": "You tend to notice small details that others might miss, especially when they affect the overall experience.", 
     "domains": {"UIUX": 2, "Software Testing": 1}},
     
    {"question": "When working on a project, you enjoy both the technical details and making sure the end result looks great and is easy to use.", 
     "domains": {"UIUX": 2, "Frontend": 1, "Full Stack": 1}},
     
    {"question": "You are drawn to problems that involve numbers, patterns, or statistics, and you enjoy discovering insights from them.", 
     "domains": {"Data Science": 2, "AI": 1,"ML":2}},
     
    {"question": "You’re often curious about how things function behind the scenes, like how websites or apps operate.", 
     "domains": {"Backend": 2, "Full Stack": 1}},
     
    {"question": "When you think about the future, you’re intrigued by the potential of technologies like artificial intelligence or cloud computing.", 
     "domains": {"AI": 2, "Cloud Development": 2, "DevOps": 1}},
     
    {"question": "You find satisfaction in working with people, organizing tasks, and making sure deadlines are met effectively.", 
     "domains": {"Project Management": 2}},
     
    {"question": "You enjoy working on tasks that involve a combination of creativity, technical skills, and ensuring the end product is well-optimized.", 
     "domains": {"Full Stack": 2, "UIUX": 1}},
]
